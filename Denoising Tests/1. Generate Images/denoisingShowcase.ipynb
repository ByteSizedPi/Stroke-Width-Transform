# %% [markdown]
# ### Setup

# %%
import deeplake
from deeplake import Dataset
from plots import plot

ds: Dataset = deeplake.load("hub://activeloop/icdar-2013-text-localize-train")


class iArray(list):
    def map(self, *functions):
        result = self
        for func in functions:
            result = list(map(func, result))
        return iArray(result)

    def show(self, img):
        plot([img, *self])
# Out:
# |
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/icdar-2013-text-localize-train
# hub://activeloop/icdar-2013-text-localize-train loaded successfully.

# %% [markdown]
# ### Idx

# %%
from random import randint
import cv2
from skimage.color import rgb2gray
from skimage.feature import canny
from skimage.restoration import denoise_bilateral, denoise_tv_chambolle
import numpy as np

idx = randint(0, 230)
# idx = 118
img = ds.images[idx].numpy()

# %% [markdown]
# ### Bilateral Filters

# %% [markdown]
# #### Standard Bilateral Filter

# %%
# iters = [cv2.bilateralFilter(img, 10, i, i) for i in range(100, 400, 100)]
# imgs = (
#     iArray([img, denoise_bilateral(img, channel_axis=-1), *iters])
#     .map(rgb2gray, canny)
#     .show(img)
# )

# %% [markdown]
# #### Bilateral Texture Filter

# %%
iters = [
    cv2.ximgproc.bilateralTextureFilter(img, sigmaAlpha=i, sigmaAvg=i)
    for i in range(-1, 600, 200)
]
imgs = iArray([img, *iters]).map(rgb2gray, canny).show(img)

# %% [markdown]
# #### Joint Bilateral Filter

# %%
iters = [
    cv2.ximgproc.jointBilateralFilter(img, img, d=5, sigmaColor=i, sigmaSpace=i)
    for i in range(-1, 600, 200)
]
imgs = iArray([img, *iters]).map(rgb2gray, canny).show(img)

# %% [markdown]
# #### Guided Filter

# %%
iters = [
    cv2.ximgproc.guidedFilter(img, img, radius=10, eps=i) for i in range(0, 800, 200)
]
imgs = iArray([img, *iters]).map(rgb2gray, canny).show(img)

# %% [markdown]
# ### Weighted Median Filter

# %%
iters = [
    cv2.ximgproc.weightedMedianFilter(img, img, r=10, sigma=i)
    for i in range(1, 800, 200)
]
imgs = iArray([img, *iters]).map(rgb2gray, canny).show(img)

# %% [markdown]
# ### Edge Preserving Filter

# %%
iters = [
    cv2.ximgproc.edgePreservingFilter(img, d=3, threshold=i) for i in range(1, 100, 20)
]
imgs = iArray([img, *iters]).map(rgb2gray, canny).show(img)

# %% [markdown]
# ### Anisotropic Diffusion

# %%
import numpy as np
iters = [
    cv2.ximgproc.anisotropicDiffusion(img, i, 100, 10) for i in np.arange(0.04, 0.2, 0.03)
]
imgs = iArray([img, *iters]).map(rgb2gray, canny).show(img)

# %% [markdown]
# ### Total Variation Filter

# %%
from skimage.restoration import denoise_tv_chambolle

iters = [denoise_tv_chambolle(img)]
imgs = iArray([img, *iters]).map(rgb2gray, canny).show(img)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from skimage.restoration import denoise_tv_chambolle
# ----> 3 iters = [denoise_tv_chambolle(img)]
#       4 imgs = iArray([img, *iters]).map(rgb2gray, canny).show(img)
#
# File c:\Users\johan\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\_shared\utils.py:282, in deprecate_kwarg.__call__.<locals>.fixed_func(*args, **kwargs)
#     279         kwargs[new_arg] = kwargs.pop(old_arg)
#     281 # Call the function with the fixed arguments
# --> 282 return func(*args, **kwargs)
#
# File c:\Users\johan\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\_shared\utils.py:348, in deprecate_multichannel_kwarg.__call__.<locals>.fixed_func(*args, **kwargs)
#     345     kwargs['channel_axis'] = convert[kwargs.pop('multichannel')]
#     347 # Call the function with the fixed arguments
# --> 348 return func(*args, **kwargs)
#
# File c:\Users\johan\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\restoration\_denoise.py:536, in denoise_tv_chambolle(image, weight, eps, max_num_iter, multichannel, channel_axis)
#     533         out[_at(c)] = _denoise_tv_chambolle_nd(image[_at(c)], weight, eps,
#     534                                                max_num_iter)
#     535 else:
# --> 536     out = _denoise_tv_chambolle_nd(image, weight, eps, max_num_iter)
#     537 return out
#
# File c:\Users\johan\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\restoration\_denoise.py:415, in _denoise_tv_chambolle_nd(image, weight, eps, max_num_iter)
#     412     g[tuple(slices_g)] = np.diff(out, axis=ax)
#     413     slices_g[ax+1] = slice(None)
# --> 415 norm = np.sqrt((g ** 2).sum(axis=0))[np.newaxis, ...]
#     416 E += weight * norm.sum()
#     417 tau = 1. / (2.*ndim)
#
# File c:\Users\johan\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:
